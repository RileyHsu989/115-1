# %% [markdown]
# <a href="https://colab.research.google.com/github/RileyHsu989/115-1/blob/main/411302875_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello\nHello')
# Out:
# Hello
# Hello

# %%
print("2026","09",sep="/")
# Out:
# 2026/09

# %%
a=5
b=2.5
c="python"
print(type(c))
# Out:
# <class 'str'>

# %%
x=20
y=30
temp=x
x=y
y=temp
print(x,y)
# Out:
# 30 20

# %%
t=8
h=8
print(id(h))
# Out:
# 10446632

# %%
x=50000*(1+0.015)**5
print(x)
# Out:
# 53864.20019421873
