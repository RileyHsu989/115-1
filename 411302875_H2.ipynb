# %% [markdown]
# <a href="https://colab.research.google.com/github/RileyHsu989/115-1/blob/main/411302875_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello\nHello')
# Out:
# Hello
# Hello

# %%
print("2026","09",sep="/")
# Out:
# 2026/09

# %%
a=5
b=2.5
c="python"
print(type(c))
# Out:
# <class 'str'>

# %%
x=20
y=30
temp=x
x=y
y=temp
print(x,y)
# Out:
# 30 20

# %%
t=8
h=8
print(id(h))
# Out:
# 10446632

# %%
x=50000*(1+0.015)**5
print(x)
# Out:
# 53864.20019421873

# %%
a=11
b=12
print("{e}\n{f}".format(e=a,f=b))
# Out:
# 11
# 12

# %%
a=11.123456
print("{0}".format(a))
print(f"{a}")
# Out:
# 11.123456
# 11.123456

# %%
x=int(input("請輸入數字:"))
print(type(x))
# Out:
# 請輸入數字:85
# <class 'int'>

# %%
x=int(input("請輸入目前金幣數量"))
y=int(input("請輸入獲得金幣數量"))
z=x+y
print(f"任務完成！你現在有{z}枚金幣 ")
# Out:
# 請輸入目前金幣數量500
# 請輸入獲得金幣數量250
# 任務完成！你現在有750枚金幣
